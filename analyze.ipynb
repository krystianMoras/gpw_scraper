# %%
# read data/gpw_data_copy.sqlite
import pandas as pd
import sqlite3
# Connect to the SQLite database
conn = sqlite3.connect('data/gpw_data.sqlite')

# %%
import pandas as pd
import plotly.express as px

# 0. Load & clean
shareholders = pd.read_sql_query("SELECT * FROM company_shareholders;", conn)
companies    = pd.read_sql_query("SELECT url, name, market_cap_mln FROM company_company;", conn)

shareholders['shares_pct'] = (
    shareholders['shares_pct']
      .str.replace('%','')
      .str.replace(',','.')
      .astype(float)
)
companies['market_cap_mln'] = (
    companies['market_cap_mln']
      .str.replace(' ','')
      .str.replace(',','.')
      .pipe(pd.to_numeric, errors='coerce')
)

# %%
# there is a typo in urls with double //. https://www.gpw.pl//spolka?isin=PLPGER000010
# remove it
companies['url'] = companies['url'].str.replace('//', '/', regex=False)

# %%
shareholders["company_url"] = shareholders["company_url"].str.replace('//', '/', regex=False)

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import numpy as np

# Data preparation as before
company_df = shareholders.merge(companies, left_on='company_url', right_on='url', how='left')
company_df = company_df[company_df['market_cap_mln'] > 0].copy()

company_df = company_df.drop_duplicates(subset=['company_url', 'name', 'shareholder'])

# add 'other' shareholder for missing percentage ownership
# first calculate shares_pct for known shareholders and then assign 100% - sum(shares_pct) to 'other' 
# add the row for 'other' shareholder
other_shareholders = company_df.groupby('name').apply(
    lambda x: pd.Series({
        'shareholder': 'Inni',
        'shares_pct': 100 - x['shares_pct'].sum(),
        'market_cap_mln': x['market_cap_mln'].iloc[0]  # use the first market cap value
    })
).reset_index()
# Append 'other' shareholders to the main DataFrame
company_df = pd.concat([company_df, other_shareholders], ignore_index=True)
# market_cap_mln  = market_cap_mln * shares_pct / 100

# Calculate total market cap per company 
company_df['total_market_cap_mln'] = company_df["market_cap_mln"]
company_df['market_cap_mln'] = company_df['total_market_cap_mln'] * company_df['shares_pct'] / 100
# Create dynamic thresholds: one per group of 20 companies
bucket_size = 20
thresholds = []
total_mkt = company_df.sort_values(by='total_market_cap_mln', ascending=False).reset_index(drop=True)
for i in range(0, len(total_mkt), bucket_size):
    bucket = total_mkt.iloc[i:i+bucket_size]
    thresholds.append(bucket['total_market_cap_mln'].min())
# Ensure thresholds are sorted ascending for correct filtering
thresholds = sorted(set(thresholds), reverse=False)

frames = []
slider_steps = []

for i, threshold in enumerate(thresholds):
    # Filter companies with market cap >= current threshold and < next threshold (if exists)
    if i < len(thresholds) - 1:
        filtered = company_df[
            (company_df['total_market_cap_mln'] >= threshold) &
            (company_df['total_market_cap_mln'] < thresholds[i + 1])
        ]
    else:
        filtered = company_df[company_df['total_market_cap_mln'] >= threshold]
    fig_tmp = px.treemap(
        filtered,
        path=['name', 'shareholder'],
        values='market_cap_mln',
        color='shares_pct',
        hover_data={
            'market_cap_mln': ':.2f',
            'shares_pct': ':.2f',
            'shareholder': True
        },
        custom_data=['shares_pct']
    )
    # Add percentage ownership to the texttemplate
    for d in fig_tmp.data:
        d.texttemplate = '%{label}<br>%{customdata[0]:.2f}% udział'
    frame = go.Frame(data=fig_tmp.data, name=str(int(threshold)))
    frames.append(frame)
    slider_steps.append({
        'method': 'animate',
        'label': f"{int(threshold)} mln+",
        'args': [
            [str(int(threshold))],
            {
                'mode': 'immediate',
                'frame': {'duration': 0, 'redraw': True},
                'transition': {'duration': 0}
            }
        ]
    })

# Initial figure = first threshold
initial_fig = px.treemap(
    company_df[company_df['market_cap_mln'] >= thresholds[0]],
    path=['name', 'shareholder'],
    values='market_cap_mln',
    color='shares_pct',
    hover_data={'market_cap_mln': ':.2f', 'shares_pct': ':.2f', 'shareholder': True},
    custom_data=['shares_pct'],
        width=1000,
    height=600,
)
for d in initial_fig.data:
    d.texttemplate = '%{label}<br>%{customdata[0]:.2f}% udział'

# Turn into go.Figure and add frames + slider
fig = go.Figure(
    data=initial_fig.data,
    layout=go.Layout(
        title="Struktura własnościowa spółek GPW (dynamiczne progi, max 20 na bucket)",
        sliders=[{
            'active': 0,
            'pad': {"t": 50},
            'currentvalue': {'prefix': 'Minimalna kapitalizacja: '},
            'steps': slider_steps
        }]
    ),
    frames=frames
)

fig.show()
fig.write_html("wlasnosc_gpw.html", include_plotlyjs="cdn", full_html=False)
# Out:
# /var/folders/1_/btj1k7sn3ls02qcwrbhlp5zc0000gp/T/ipykernel_34673/2309394659.py:15: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import numpy as np

# Data preparation as before
shareholders_df = shareholders.merge(companies, left_on='company_url', right_on='url', how='left')
shareholders_df['stake_value_mln'] = shareholders_df['shares_pct'] / 100 * shareholders_df['market_cap_mln']
shareholders_df = shareholders_df[shareholders_df['stake_value_mln'] > 0].copy()

# Calculate total stake value per shareholder
total_stake = shareholders_df.groupby('shareholder')['stake_value_mln'].sum().reset_index()
total_stake.columns = ['shareholder', 'total_stake_value_mln']

# Sort by total stake value descending
total_stake = total_stake.sort_values('total_stake_value_mln', ascending=False).reset_index(drop=True)

# Create dynamic thresholds: one per group of 20 shareholders
bucket_size = 20
thresholds = []
for i in range(0, len(total_stake), bucket_size):
    bucket = total_stake.iloc[i:i+bucket_size]
    thresholds.append(bucket['total_stake_value_mln'].min())
# Ensure thresholds are sorted descending for correct filtering
thresholds = sorted(set(thresholds), reverse=False)

# Merge back to get total stake value for each row
sh_df = shareholders_df.merge(total_stake, on='shareholder', how='left')
# Calculate percentage of stake in total stake for each row
sh_df['stake_pct_of_total'] = 100 * sh_df['stake_value_mln'] / sh_df['total_stake_value_mln']

frames2 = []
slider_steps2 = []

for i, threshold in enumerate(thresholds):
    # Filter shareholders with total stake value >= current threshold and < next threshold (if exists)
    if i < len(thresholds) - 1:
        filtered = sh_df[
            (sh_df['total_stake_value_mln'] >= threshold) &
            (sh_df['total_stake_value_mln'] < thresholds[i + 1])
        ]
    else:
        filtered = sh_df[sh_df['total_stake_value_mln'] >= threshold]

    fig_tmp = px.treemap(
        filtered,
        path=['shareholder', 'name'],
        values='stake_value_mln',
        color='shares_pct',
        hover_data={
            'stake_value_mln': ':.2f',
            'shares_pct': ':.2f',
            'market_cap_mln': ':.2f',
            'total_stake_value_mln': ':.2f',
            'stake_pct_of_total': ':.2f'
        },
        custom_data=['stake_pct_of_total']
    )
    # Add percentage of stake in total stake to the texttemplate
    for d in fig_tmp.data:
        d.texttemplate = '%{label}<br>%{value:.2f}mln<br>%{customdata[0]:.2f}% portfela'
    frame = go.Frame(data=fig_tmp.data, name=str(int(threshold)))
    frames2.append(frame)
    slider_steps2.append({
        'method': 'animate',
        'label': f"{int(threshold)} mln+",
        'args': [
            [str(int(threshold))],
            {
                'mode': 'immediate',
                'frame': {'duration': 0, 'redraw': True},
                'transition': {'duration': 0}
            }
        ]
    })

# Initial figure = first threshold
initial_fig2 = px.treemap(
    sh_df[sh_df['total_stake_value_mln'] >= thresholds[0]],
    path=['shareholder', 'name'],
    values='stake_value_mln',
    color='shares_pct',
    hover_data={
        'stake_value_mln': ':.2f',
        'shares_pct': ':.2f',
        'market_cap_mln': ':.2f',
        'total_stake_value_mln': ':.2f',
        'stake_pct_of_total': ':.2f'
    },

    custom_data=['stake_pct_of_total']
)
for d in initial_fig2.data:
    d.texttemplate = '%{label}<br>%{value:.2f}mln<br>%{customdata[0]:.2f}% portfela'

fig2 = go.Figure(
    data=initial_fig2.data,
    layout=go.Layout(
        title="Najwięksi akcjonariusze GPW i ich udziały (%) (dynamiczne progi, max 20 na bucket)",
        sliders=[{
            'active': 0,
            'pad': {"t": 50},
            'currentvalue': {'prefix': 'Minimalna wartość portfela: '},
            'steps': slider_steps2
        }]
    ),
    frames=frames2
)

fig2.show()
fig2.write_html("akcjonariusze_gpw.html", include_plotlyjs="cdn", full_html=False)

# %%
# see descriptions of companies

companies_desc    = pd.read_sql_query("SELECT name, description FROM company_company;", conn)
# pretty print
companies_desc['description'] = companies_desc['description'].str.replace('\n', ' ')
companies_desc['description'] = companies_desc['description'].str.replace('  ', ' ')
# Display descriptions
for index, row in companies_desc.iterrows():
    print(f"Company: {row['name']}\nDescription: {row['description']}\n")
# Out:
# Company: COALENERG
# Description: Grupa specjalizuje się w wydobyciu, wzbogacaniu i sprzedaży węgla energetycznego i koksowego. Dostarcza surowiec do największych zakładów wytwórczych energii elektrycznej i ciepła oraz zakładów hutniczych na Ukrainie. Spółka eksportuje również węgiel do elektrowni w Turcji, Mołdawii, Bułgarii i Słowacji. Działalność grupy koncentruje się na efektywnym wydobyciu i dystrybucji węgla, odpowiadając na potrzeby energetyczne i przemysłowe w regionie.
#
# Company: ALLEGRO
# Description: Grupa jest właścicielem wiodącej platformy e-commerce w Polsce - Allegro.pl, która przyciąga miesięcznie około 20 milionów użytkowników. Portfolio spółki obejmuje również popularną porównywarkę cenową Ceneo.pl. Ponadto, grupa zarządza serwisem eBilet, specjalizującym się w sprzedaży biletów na różnorodne wydarzenia. Oferta grupy obejmuje szeroki zakres produktów i usług, w tym program lojalnościowy Allegro Smart! oraz usługi logistyczne Allegro Fulfillment. Spółka rozwija też sieć automatów paczkowych Allegro One Box.
#
# Company: ZABKA
#
# Company: KPPD
# Description: Grupa działa na rynku drzewnym, tartacznym i ogrodowym. Przedmiotem działalności jest pozyskiwanie i produkcja wyrobów z drewna i materiałów drewnopochodnych. Spółka specjalizuje się w wytwarzaniu tarcicy, wyrobów fryzarskich oraz płyt klejonych. Produkcja odbywa się w kilkunastu zakładach zlokalizowanych na terenie kraju. Firma zajmuje pozycję jednego z czołowych producentów tarcicy w Polsce, oferując szeroki asortyment produktów drewnianych dla różnych sektorów przemysłu i klientów indywidualnych.
#
# Company: PGE
# Description: Grupa PGE jest zintegrowanym pionowo podmiotem energetycznym, działającym w całym łańcuchu wartości energii elektrycznej. To jeden z największych graczy sektora elektroenergetycznego w Polsce. Główne obszary działalności Grupy obejmują wydobycie węgla brunatnego, wytwarzanie energii elektrycznej z paliw kopalnych (węgiel brunatny, węgiel kamienny, gaz ziemny) oraz z odnawialnych źródeł (elektrownie wodne, farmy wiatrowe, biomasa), dystrybucję i sprzedaż energii elektrycznej odbiorcom końcowym. Grupa prowadzi również obrót hurtowy energią elektryczną, gazem, uprawnieniami do emisji CO2 i świadectwami pochodzenia, świadczy usługi systemowe dla bezpieczeństwa dostaw energii oraz prowadzi działalność ciepłowniczą i w obszarze gospodarki obiegu zamkniętego. Grupa posiada zdywersyfikowany miks wytwórczy oparty zarówno na paliwach konwencjonalnych, jak i odnawialnych źródłach energii.
#
# Company: PURE
# Description: Spółka specjalizuje się w pracach badawczo-rozwojowych nad innowacyjnymi lekami biologicznymi, testami diagnostycznymi i wyrobami medycznymi o zastosowaniu terapeutycznym. Działalność koncentruje się na realizacji dwóch projektów badawczych ukierunkowanych na odkrycie i skomercjalizowanie kandydatów na leki o wysokim potencjale rynkowym w leczeniu schorzeń onkologicznych. Równolegle prowadzone są działania mające na celu zawarcie umów partneringowych ze światowymi firmami farmaceutycznymi. Spółka oferuje również usługi badań kontraktowych w zakresie selekcji cząsteczek aktywnych do zastosowań medycznych oraz produkcji, oczyszczania i analizy rekombinowanych białek.
#
# Company: DIGITREE
# Description: Grupa działa w branży digital marketingu, dostarczając efektywne rozwiązania digitalowe. Oferuje kompleksową obsługę obecności klientów w Internecie, wykorzystując autorskie narzędzia technologiczne, partnerstwo z globalnymi liderami technologii, sztuczną inteligencję, własne zasoby bazodanowe oraz wiedzę specjalistów. Główne obszary działalności obejmują generowanie sprzedaży i leadów, precyzyjne docieranie do grup docelowych, e-mail marketing i marketing automation, wdrażanie platform e-commerce, doradztwo strategiczne, tworzenie strategii marek i sprzedaży, rozwijanie brand awareness poprzez współpracę z influencerami, dostarczanie mediów reklamowych oraz monetyzację baz e-mailingowych i ruchu na stronach www.
#
# Company: FMG
# Description: ONE SA prowadzi działalność w trzech głównych obszarach. Spółka zajmuje się sprzedażą energii elektrycznej i gazu ziemnego do odbiorców końcowych. Drugim filarem jest obrót nieruchomościami, obejmujący zakup, sprzedaż oraz wynajem obiektów komercyjnych i mieszkalnych. Trzecim obszarem działalności jest świadczenie usług telekomunikacyjnych, w tym telefonii stacjonarnej i mobilnej oraz dostępu do internetu. Firma koncentruje się na rozwoju tych trzech segmentów, dążąc do zwiększania udziału w rynku i poszerzania bazy klientów.
#
# Company: GREENX
# Description: Grupa realizuje inwestycję budowy kopalni Jan Karski w Lubelskim Zagłębiu Węglowym. Kopalnia będzie prowadziła eksploatację złoża Lublin, którego całkowite szacunkowe zasoby węgla wynoszą 728 mln ton. Spółka jest notowana na giełdach w Australii (ASX), Londynie (LSE) i Warszawie (GPW). Działalność grupy koncentruje się na nowoczesnym poszukiwaniu i wydobyciu surowców, ze szczególnym uwzględnieniem rozwoju projektu Jan Karski. Inwestycja ta ma strategiczne znaczenie dla sektora wydobywczego w regionie.
#
# Company: EUROHOLD
# Description: Eurohold Bulgaria AD jest wiodącą niezależną grupą biznesową w Europie Środkowej i Południowo-Wschodniej, zajmującą kluczowe pozycje w sektorach ubezpieczeń i energetyki. Jej główna działalność obejmuje tworzenie, nabywanie i zarządzanie udziałami oraz finansowanie powiązanych spółek. Eurohold jest właścicielem dużej grupy energetycznej w Bułgarii - grupy Electrohold. Posiada również Euroins Insurance Group, dużą niezależną grupę ubezpieczeniową w regionie CEE/SEE pod względem składki przypisanej brutto. Eurohold posiada spółki zależne w sektorach energetyki, ubezpieczeń oraz pośrednictwa inwestycyjnego i zarządzania aktywami. Firma działa poprzez 4 spółki zależne, 2 dedykowane spółki rozwoju biznesu energetycznego oraz 17 spółek operacyjnych w 12 krajach europejskich. Eurohold jest spółką publiczną notowaną na giełdach w Sofii i Warszawie. Grupa posiada doświadczony zespół zarządzający i wysokie standardy ładu korporacyjnego. Eurohold zarządza i wspiera swoją grupę ekonomiczną poprzez strategię, zarządzanie ryzykiem, finansowanie, kontrolę, komunikację, doradztwo prawne, zasoby ludzkie i systemy informatyczne.
#
# Company: SOPHARMA
# Description: Grupa Sopharma jest wiodącym bułgarskim producentem, eksporterem i lokalnym dystrybutorem produktów farmaceutycznych, z silną obecnością w Europie Wschodniej i Południowo-Wschodniej. Grupa oferuje szeroki asortyment leków na receptę, produktów bez recepty, suplementów diety, kosmetyków i wyrobów medycznych. Jej główne działania obejmują produkcję wyrobów farmaceutycznych, głównie leków generycznych, substancji ziołowych i suplementów diety, przede wszystkim przez Sopharma AD. Grupa produkuje również wyroby medyczne i kosmetyki, takie jak plastry, bandaże i artykuły sanitarno-higieniczne w zakładzie w Sandanski. Dystrybucja farmaceutyków, materiałów medycznych, witamin, suplementów diety, kosmetyków i innych produktów odbywa się głównie przez Sopharma Trading w Bułgarii i Serbii. Grupa działa w 41 krajach, a kluczowe rynki to Bułgaria, Rosja, Ukraina, Kazachstan i Polska.
#
# Company: AGROTON
# Description: Spółka to pionowo zintegrowana grupa rolnicza działająca we wschodniej Ukrainie. Głównym obszarem działalności jest produkcja płodów rolnych, ze szczególnym uwzględnieniem pszenicy i słonecznika. Grupa zajmuje się również przetwórstwem, magazynowaniem i sprzedażą nasion zbóż. Dodatkowo prowadzi hodowlę zwierząt gospodarskich oraz produkcję artykułów spożywczych. Działalność obejmuje pełen cykl produkcyjny, od uprawy roślin po dystrybucję gotowych produktów.
#
# Company: SANTANDER
# Description: Santander to największy uniwersalny bank w strefie euro i jedna z czołowych grup finansowych na świecie. Działa w kluczowych segmentach: bankowości detalicznej, komercyjnej i korporacyjnej, zarządzaniu aktywami i ubezpieczeniach oraz płatnościach. Grupa koncentruje się na 10 głównych rynkach w Europie i Ameryce. Jest liderem w Hiszpanii i wiodącym bankiem w kilku krajach Ameryki Łacińskiej. Posiada silną pozycję w Wielkiej Brytanii, Portugalii, Polsce i północno-wschodniej części USA. Santander oferuje szeroką gamę produktów i usług finansowych dla klientów indywidualnych, małych i średnich przedsiębiorstw oraz dużych korporacji. Bank rozwija cyfrowe kanały obsługi i innowacyjne rozwiązania technologiczne. Santander angażuje się w zrównoważony rozwój i odpowiedzialne praktyki bankowe. W Polsce Grupa posiada większościowy udział w Santander Bank Polska, jednym z największych banków w kraju.
#
# Company: MBWS
# Description: Marie Brizard Wine & Spirits S.A. to grupa produkująca i oferująca napoje alkoholowe oraz wina. Firma specjalizuje się w markach o długiej tradycji, łącząc je z innowacyjnym podejściem. Portfolio grupy obejmuje wiodące marki w różnych segmentach rynku, w tym William Peel, Sobieski, Marie Brizard i Cognac Gautier. Grupa działa głównie w Europie i Stanach Zjednoczonych, oferując produkty zarówno w kanale off-trade (sklepy detaliczne), jak i on-trade (lokale gastronomiczne). Marie Brizard Wine & Spirits prowadzi również działalność w zakresie usług przemysłowych, w tym produkcji i butelkowania dla marek własnych sieci handlowych.
#
# Company: ESTAR
# Description: Enefi plc specjalizuje się w dostarczaniu rozwiązań z zakresu efektywności energetycznej i odnawialnych źródeł energii. Firma koncentruje się na projektowaniu, instalacji i zarządzaniu systemami energetycznymi dla klientów z sektora publicznego i prywatnego. Główne obszary działalności obejmują modernizację systemów grzewczych, wdrażanie energooszczędnego oświetlenia publicznego oraz integrację odnawialnych źródeł energii w istniejące infrastruktury. Enefi oferuje kompleksowe usługi, od audytów energetycznych po realizację projektów i długoterminowe zarządzanie systemami. Spółka aktywnie działa w Europie Środkowej i Wschodniej, ze szczególnym uwzględnieniem Węgier i okolicznych krajów. Enefi wykorzystuje zaawansowane technologie do optymalizacji zużycia energii, redukcji kosztów operacyjnych i minimalizacji wpływu na środowisko. Firma angażuje się również w projekty badawczo-rozwojowe, dążąc do innowacji w dziedzinie efektywności energetycznej. Enefi współpracuje z lokalnymi władzami, instytucjami publicznymi i przedsiębiorstwami, oferując rozwiązania dostosowane do indywidualnych potrzeb klientów.
#
# Company: MOL
# Description: Grupa jest czołową zintegrowaną firmą w sektorze naftowo-gazowniczym w Środkowej Europie. Spółka prowadzi działalność w zakresie poszukiwania i wydobycia ropy naftowej i gazu, rafinacji ropy naftowej oraz sprzedaży hurtowej i detalicznej produktów rafineryjnych. Grupa utrzymuje produkcję powyżej 90 mboepd. W segmencie downstream popyt pozostaje silny, a sprzedaż i marże rafineryjne wzrosły rok do roku. Wyniki segmentu usług konsumenckich poprawiły się głównie dzięki większej sprzedaży paliw i poprawie marży na produktach pozapaliwowych. Spółka prowadzi również usługi gospodarki o obiegu zamkniętym, w tym system kaucyjny. Grupa działa w wielu krajach regionu, kontrolując m.in. słowacki Slovnaft i posiadając udziały w chorwackiej INA.
# Description: Grupa prowadzi działalność na rynku nieruchomości jako inwestor, deweloper i zarządca, a także w branży hotelarskiej. Koncentruje się głównie na rynkach Czech i Polski. Portfel nieruchomości spółki obejmuje 8 obiektów o łącznej powierzchni najmu 160 000 m2 oraz bank ziemi o powierzchni ponad 18 mln m2. Grupa osiąga przychody z najmu, sprzedaży usług oraz działalności hotelowej.
#
# Company: KERNEL
# Description: Spółka prowadzi zdywersyfikowaną działalność rolniczą w regionie Morza Czarnego, koncentrując się na produkcji i eksporcie zbóż oraz oleju słonecznikowego z Ukrainy. Grupa jest jednym z wiodących dostawców produktów rolnych na rynki międzynarodowe. Działalność obejmuje uprawę zbóż, przetwórstwo nasion oleistych oraz zarządzanie infrastrukturą logistyczną, w tym terminalami eksportowymi. Spółka dba o zrównoważony rozwój i stosuje nowoczesne technologie w rolnictwie.
#
# Company: SADOVAYA
# Description: Grupa specjalizuje się w wydobyciu i przetwarzaniu węgla oraz obrocie węglem na Ukrainie. Spółka prowadzi działalność w sektorze surowcowym, koncentrując się głównie na branży węglowej. W portfolio grupy znajdują się dwie kopalnie zlokalizowane w regionie Donbasu. Działalność obejmuje również przetwarzanie odpadów powęglowych. Jako czołowy prywatny podmiot w ukraińskiej branży węglowej, spółka odgrywa istotną rolę na lokalnym rynku surowcowym.
#
# Company: IMCOMPANY
# Description: Grupa prowadzi działalność rolniczą na Ukrainie. Główne obszary działalności obejmują uprawę zbóż i roślin oleistych oraz ich przechowywanie i przetwarzanie. Spółka należy do czołówki ukraińskich producentów rolnych. Grupa kontroluje 120,3 tys. ha gruntów rolnych wysokiej jakości (120,0 tys. ha pod uprawą) w regionach Sumy, Połtawa i Czernihów w północnej i centralnej Ukrainie. Uprawiane zboża i rośliny oleiste sprzedawane są zarówno na rynku ukraińskim, jak i na eksport.
#
# Company: KSGAGRO
# Description: Grupa jest zintegrowanym pionowo podmiotem rolniczym działającym w obwodzie dniepropietrowskim na Ukrainie. Prowadzi działalność w kluczowych segmentach rynku rolnego, obejmującą hodowlę trzody chlewnej, przetwórstwo mięsa wieprzowego oraz uprawę pszenicy i słonecznika. Spółka koncentruje się na trzech uprawach ozimych, dwóch jarych oraz hodowli świń jednej rasy. Produkty grupy to podstawowe artykuły spożywcze, na które utrzymuje się stały popyt. W pierwszym kwartale 2024 roku grupa prowadziła zasiewy słonecznika na obszarze 7700 hektarów, pszenicy na 2200 hektarach i rzepaku na 1430 hektarach.
#
# Company: COALENERG
# Description: Grupa specjalizuje się w wydobyciu, wzbogacaniu i sprzedaży węgla energetycznego i koksowego. Dostarcza surowiec do największych zakładów wytwórczych energii elektrycznej i ciepła oraz zakładów hutniczych na Ukrainie. Spółka eksportuje również węgiel do elektrowni w Turcji, Mołdawii, Bułgarii i Słowacji. Działalność grupy koncentruje się na efektywnym wydobyciu i dystrybucji węgla, odpowiadając na potrzeby energetyczne i przemysłowe w regionie.
#
# Company: ALLEGRO
# Description: Grupa jest właścicielem wiodącej platformy e-commerce w Polsce - Allegro.pl, która przyciąga miesięcznie około 20 milionów użytkowników. Portfolio spółki obejmuje również popularną porównywarkę cenową Ceneo.pl. Ponadto, grupa zarządza serwisem eBilet, specjalizującym się w sprzedaży biletów na różnorodne wydarzenia. Oferta grupy obejmuje szeroki zakres produktów i usług, w tym program lojalnościowy Allegro Smart! oraz usługi logistyczne Allegro Fulfillment. Spółka rozwija też sieć automatów paczkowych Allegro One Box.
#
# Company: ZABKA
# Description: Grupa prowadzi sieć sklepów convenience, obejmującą placówki stacjonarne i autonomiczne. Sklepy oferują produkty spożywcze, w tym dania gotowe, kawę, przekąski i kanapki oraz usługi dodatkowe takie jak odbiór paczek, gry losowe i płatności rachunków. Działalność uzupełniają usługi cyfrowe: aplikacja mobilna, catering dietetyczny (Maczfit), platforma do zamawiania diet pudełkowych (Dietly) oraz dostawy zakupów online (delio, Jush!). Infrastrukturę logistyczną w Polsce stanowi osiem centrów dystrybucyjnych i 19 obiektów cross-dock. W Rumunii grupa działa poprzez sieć dystrybucyjną DRIM.
#
# Company: ASTARTA
# Description: Grupa specjalizuje się w produkcji cukru, uprawie roślin, przetwórstwie soi i hodowli bydła. Grunty uprawne, cukrownie, zakłady przetwórstwa soi oraz hodowle bydła są zlokalizowane głównie w obwodach połtawskim, winnickim, chmielnickim, czernihowskim, żytomierskim, tarnopolskim i charkowskim Ukrainy. Działalność grupy jest zintegrowana pionowo, ponieważ cukier produkowany jest głównie z własnych buraków cukrowych, a przetwarzana soja również pochodzi z własnych upraw. Eksport stanowi znaczącą część przychodów, obejmując m.in. zboża, cukier i produkty sojowe.
#
# Company: MILKILAND
# Description: Grupa jest czołowym producentem wyrobów mlecznych w Europie Środkowo-Wschodniej. Specjalizuje się w produkcji serów, jogurtów, masła i innych produktów mleczarskich. Spółka posiada zakłady produkcyjne w Polsce i na Ukrainie. Jej produkty są eksportowane do ponad 30 krajów na całym świecie. Grupa oferuje szeroką gamę wyrobów mlecznych, koncentrując się na wysokiej jakości i innowacyjności. Dzięki wieloletniemu doświadczeniu i nowoczesnym technologiom, spółka dostarcza konsumentom produkty spełniające najwyższe standardy bezpieczeństwa żywności.
#
# Company: PHOTON
# Description: Grupa jest globalnym dostawcą kompleksowych rozwiązań energii odnawialnej. Działalność obejmuje rozwój, budowę i eksploatację systemów fotowoltaicznych oraz lokalne programy handlu energią i elastyczności. Spółka jest również niezależnym producentem energii z rosnącym portfelem elektrowni słonecznych. Oferuje rozwiązania fotowoltaiczne dla budynków i innych obiektów, a także pełen zakres usług eksploatacji i konserwacji systemów PV. Poprzez dedykowany sklep internetowy dostarcza komponenty fotowoltaiczne instalatorom w całej Europie. Jako licencjonowany trader energii w 6 krajach, kupuje i dostarcza energię ze źródeł odnawialnych. Grupa działa w 9 krajach na 3 kontynentach.
#
# Company: PLAZACNTR
# Description: Spółka jest wiodącym deweloperem centrów handlowo-rozrywkowych na rynkach wschodzących. Koncentruje się na budowie nowych obiektów oraz przebudowie istniejących, gdy dostrzega odpowiedni potencjał. Grupa prowadzi działalność w stolicach państw Europy Środkowo-Wschodniej oraz największych miastach regionalnych. Rozszerzyła także zasięg geograficzny poza Europę, wchodząc na rynek indyjski. Działalność obejmuje rozwój, budowę, wynajem, zarządzanie i sprzedaż centrów handlowych. Spółka posiada projekty w różnych fazach rozwoju i działalności operacyjnej.
#
# Company: PEPCO
# Description: Grupa prowadzi paneuropejską sieć dyskontowych sklepów wielobranżowych pod markami Pepco, Dealz i Poundland. Oferta obejmuje odzież, artykuły gospodarstwa domowego, zabawki, produkty sezonowe oraz artykuły szybkozbywalne (FMCG). Na koniec marca 2024 roku sieć liczyła 4845 placówek w kilkunastu krajach Europy. Sklepy Pepco oferują głównie odzież i artykuły dla domu, natomiast Poundland i Dealz specjalizują się w produktach FMCG oraz artykułach ogólnego przeznaczenia. Grupa systematycznie rozszerza swoją obecność w Europie Środkowo-Wschodniej oraz Zachodniej, koncentrując się na rynkach oferujących najwyższe stopy zwrotu.
#
# Company: 11BIT
# Description: Grupa zajmuje się tworzeniem i wydawaniem gier multiplatformowych. Działając w modelu niezależnym, prowadzi wszystkie etapy produkcji gier - od koncepcji, przez marketing, po dystrybucję cyfrową. Portfolio obejmuje własne tytuły jak "Frostpunk" i "This War of Mine" oraz gry zewnętrznych deweloperów, m.in. "The Invincible", "The Thaumaturge" i "INDIKA". Spółka przygotowuje się do premier gier "Frostpunk 2" i "The Alters". Prowadzi również prace nad rozszerzeniem działalności na inne pola eksploatacji posiadanych marek, jak gry planszowe czy literatura.
#
# Company: DIGITANET
# Description: Grupa koncentruje działalność na rynku cyfrowej reklamy zewnętrznej (Digital Out Of Home). Zarządza ogólnopolską siecią 20 tysięcy ekranów reklamowych LED oraz LCD, zdywersyfikowanych pod względem wielkości i lokalizacji. Nośniki znajdują się w centralnych punktach miast, na dworcach kolejowych, lotniskach, w galeriach handlowych, sklepach wielkopowierzchniowych oraz przy głównych arteriach komunikacyjnych. Dzięki posiadanej infrastrukturze, spółka oferuje zasięgi reklamowe w skali kraju oraz organizację kampanii promocyjnych na nośnikach cyfrowych. Pośrednictwem w sprzedaży oferty reklamowej zajmuje się spółka zależna Screen Network sp. z o.o. Udział przychodów z reklamy zewnętrznej w łącznej sprzedaży wynosi 98%.
#
# Company: 4MASS
# Description: Spółka zajmuje się produkcją i dystrybucją kosmetyków z kategorii manicure, pedicure oraz makeup. Oferuje produkty pod własnymi markami Claresa, PALU, Stylistic Salon System i BRUSHUP oraz wytwarza kosmetyki w modelu private label dla sieci handlowych i właścicieli marek. Główne produkty to lakiery hybrydowe i żele budujące. Grupa prowadzi sprzedaż hurtową oraz detaliczną poprzez własne sklepy internetowe. Większość przychodów pochodzi z rynku krajowego, a pozostała część z eksportu do krajów UE. Spółka rozwija także innowacyjne rozwiązania w zakresie kosmetyków stymulujących wzrost włosów i pielęgnacji skóry.
#
# Company: BIGCHEESE
# Description: Działalność spółki koncentruje się na produkcji i wydawaniu gier komputerowych na platformy PC oraz konsole. Głównym produktem jest seria "Cooking Simulator", która obejmuje podstawową grę oraz kilka dodatków DLC. Spółka kontynuuje monetyzację tej serii poprzez planowane wydanie nowego dodatku DLC Sushi oraz przygotowanie kolejnych DLC do wersji PC. Prowadzone są również prace nad grą "Cooking Simulator 2". Firma skupia się na wydawaniu istniejących dodatków DLC na platformy, na których nie są one jeszcze dostępne, co ma na celu poszerzenie zasięgu i zwiększenie przychodów z tego tytułu.
#
# Company: ABPL
# Description: Grupa jest największą siecią dystrybucji w regionie CEE, posiadającą 16 500 partnerów handlowych. W stałej ofercie znajduje się ponad 96 000 produktów 800 światowych marek. Spółka prowadzi działalność w Polsce, Czechach i na Słowacji, sprzedając produkty czołowych producentów nowoczesnych technologii. Oprócz ugruntowanej pozycji na rynku sprzętu IT, grupa zajmuje się dystrybucją elektroniki użytkowej, produktów związanych z telefonią komórkową i naziemną telewizją cyfrową DVB-T, rozwiązaniami cloud computing oraz AGD. Ofertę handlową uzupełniają dodatkowe usługi.
#
# Company: ASSECOBS
# Description: Asseco Business Solutions SA jest częścią międzynarodowej Grupy Asseco Poland SA. Spółka dostarcza kompleksowe rozwiązania informatyczne wspierające procesy biznesowe w przedsiębiorstwach różnej wielkości. Oferta obejmuje systemy klasy ERP, aplikacje mobilne SFA i FFA, platformy wymiany danych oraz oprogramowanie dla branży handlu detalicznego. Asseco Business Solutions SA posiada dwa własne Data Center. Firma oferuje rozwiązania oparte na technologiach Oracle, Microsoft oraz autorskim systemie bazodanowym MacroBASE. Oprogramowanie Asseco Business Solutions SA wspiera funkcjonowanie kilkudziesięciu tysięcy przedsiębiorstw w Polsce i za granicą. Spółka prowadzi wdrożenia w wielu krajach Europy.
#
# Company: ACAUTOGAZ
# Description: Spółka specjalizuje się w produkcji i dostawie samochodowych instalacji gazowych. Oferta obejmuje również wytwarzanie modułów elektronicznych i mechanicznych oraz elementów elektroniki i wiązek elektrycznych dla przemysłu motoryzacyjnego, w tym zestawów do haków holowniczych. Grupa prowadzi także dystrybucję innych części i akcesoriów samochodowych, ze szczególnym uwzględnieniem produktów pochodzenia włoskiego. Działalność koncentruje się na dostarczaniu wysokiej jakości rozwiązań dla sektora motoryzacyjnego, łącząc kompetencje w obszarze instalacji gazowych z szerokim asortymentem komponentów elektronicznych i mechanicznych.
#
# Company: ACTION
# Description: Centrum Dystrybucji E-commerce Action (ang. Action E-Commerce Distribution Centre) zarządza różnymi aspektami handlu hurtowego i detalicznego w Internecie, posiadając w ofercie tysiące produktów z różnych kategorii. Główne segmenty biznesu B2B realizowanego przez własną, e-commercową platformę handlową i-serwis to: ACTION Business Center - odpowiada za dystrybucję rozwiązań zaawansowanych; Home and Living - oferuje produkty do domu i biura, Action Global - prowadzi hurtową sprzedaż internetową zagranicą. W segmencie biznesu B2C Spółka posiada własne sklepy: 1.pl, sferis.pl, krakvet.pl, bron.pl, pomocedlaseniora.pl sprzedające bezpośrednio lub poprzez znane platformy aukcyjne. Jest też producentem profesjonalnego sprzętu dla graczy komputerowych ACTINA oraz nowoczesnych i funkcjonalnych produktów do biura oraz domu Activejet.
#
# Company: MANYDEV
# Description: Spółka zajmuje się tworzeniem i wydawaniem gier komputerowych, głównie na platformę PC. Obecnie posiada prawa do udziału w zyskach z kilku projektów gier, które zostały sprzedane innym podmiotom w celu ich ukończenia i wydania. Wśród tych tytułów znajdują się "My Museum", "Corsair's Madness" oraz "Sword&Shield Simulator". Dodatkowo, spółka oczekuje na potencjalne przychody z gier "Parasight" i "Illusion Lands", które są rozwijane przez zewnętrznych deweloperów. Portfolio spółki obejmuje różnorodne gatunki gier.
#
# Company: ADIUVO
# Description: Grupa skupia się na selekcji, rozwoju, finansowaniu i komercjalizacji innowacyjnych projektów biomedycznych na rynku międzynarodowym. Działalność koncentruje się głównie na zastosowaniu nowych produktów lub technologii w leczeniu różnych chorób i stanów chorobowych oraz na potrzeby diagnostyczne. Spółka rozwija technologie medyczne, zwłaszcza w obszarach monitorowania zdrowia, optymalizacji badań klinicznych oraz zarządzania stylem życia. Grupa Airway Medix rozwija urządzenia stosowane na oddziałach intensywnej terapii oraz anestezjologii. Portfolio obejmuje 4 zaawansowane technologie medyczne, z których 3 są w procesie transferu dokumentacji regulacyjnej oraz technologii do nowych partnerów produkcyjnych.
#
# Company: SATIS
# Description: Grupa koncentruje się na działalności związanej z oprogramowaniem. Zakres usług obejmuje outsourcing, w tym wynajem pracowników do prac zleconych oraz pośrednictwo handlowe. Spółka świadczy te usługi wykorzystując pracowników zatrudnionych na podstawie umów zlecenia i umów o dzieło. Działalność w tym modelu biznesowym rozpoczęto w 2019 roku. Obecnie grupa wyhamowała rozwój działalności operacyjnej, skupiając się na rozwiązaniu sporu prawnego dotyczącego odzyskania majątku spółki.
#
# Company: AGORA
# Description: Agora SA jest jedną z największych spółek medialnych w Polsce. Działa w segmencie kinowym poprzez sieć kin Helios oraz spółkę dystrybucji filmowej Next Film. Wydaje Gazetę Wyborczą w wersji drukowanej i cyfrowej. Prowadzi działalność w segmencie reklamy zewnętrznej poprzez AMS SA. Posiada portfolio internetowe z serwisami Gazeta.pl i Sport.pl. W segmencie radiowym działa poprzez stacje TOK FM, Radio Złote Przeboje, Radio Zet i Chillizet. Wydaje książki i płyty pod marką Wydawnictwo Agora. Firma jest obecna również na rynku gastronomicznym poprzez sieć restauracji.
#
# Company: AIRWAY
# Description: Spółka koncentruje się na pracach badawczo-rozwojowych i komercjalizacji nowatorskich urządzeń do jednorazowego stosowania u pacjentów wentylowanych mechanicznie na Oddziałach Intensywnej Opieki Medycznej, u pacjentów z zagrożeniem życia oraz na oddziałach anestezjologii. W portfolio posiada 4 zaawansowane technologie medyczne. Trzy z nich są w procesie transferu dokumentacji regulacyjnej oraz technologii do nowych partnerów produkcyjnych (Oral Care, Cuff Pressure Technology oraz Closed Suction System), jedna - platforma LMA znajduje się na etapie prac rozwojowych. Technologie i produkty chronione są prawami własności intelektualnej. Spółka posiada 28 rodzin patentowych, w tym 26 przyznanych i aktywnych patentów, z czego 13 w Stanach Zjednoczonych.
#
# Company: ALIOR
# Description: Alior Bank SA jest uniwersalnym bankiem depozytowo-kredytowym, obsługującym osoby fizyczne, prawne i inne podmioty krajowe i zagraniczne. Podstawowa działalność Banku obejmuje prowadzenie rachunków bankowych, udzielanie kredytów i pożyczek, emitowanie bankowych papierów wartościowych oraz prowadzenie skupu i sprzedaży wartości dewizowych. Bank prowadzi także działalność maklerską, doradztwo i pośrednictwo finans
# Description: Grupa działa w trzech segmentach biznesowych: Energia Elektryczna, Woda i Ciepło oraz Gaz. Dostarcza na rynek rozwiązania w zakresie opomiarowania mediów użytkowych (liczniki energii elektrycznej, wodomierze, ciepłomierze, gazomierze), a także zaawansowane technologicznie systemy dla inteligentnych sieci. Oferta obejmuje elektroniczne liczniki energii, urządzenia do rozdziału energii, systemy sterowania i nadzoru, systemy do zarządzania danymi pomiarowymi oraz rozwiązania dla OZE. W segmencie Gaz spółka oferuje gazomierze miechowe, w tym inteligentne, z funkcją zdalnego odczytu. Segment Woda i Ciepło dostarcza wodomierze mechaniczne i ultradźwiękowe, ciepłomierze oraz systemy zdalnego odczytu i rozliczeń zużycia mediów.
#
# Company: APLISENS
# ...
#
# Company: WIRTUALNA
# Description: Grupa jest właścicielem jednego z dwóch najpopularniejszych w Polsce horyzontalnych portali internetowych - Wirtualnej Polski. Prowadzi również portal o2 oraz specjalistyczne portale wertykalne, w tym m.in. Money.pl, Dobreprogramy, Sportowe Fakty, Pudelek, abcZdrowie i Parenting.pl. Oferuje usługi subskrypcyjne, w tym dostęp do programów telewizyjnych (Pilot WP) i audiobooków (Audioteka). W obszarze e-commerce działa głównie w branży turystycznej (Wakacje.pl, Nocowanie.pl, Grupa Szallas) oraz finansowej (Superauto.pl, Totalmoney.pl). Grupa prowadzi również działalność na rynku reklamy internetowej, oferując klientom szeroką gamę produktów reklamowych.
#
# Company: SECOGROUP
# Description: Grupa jest globalnym producentem kompletnych rozwiązań do obróbki cieplnej metali. Specjalizacja obejmuje piece przemysłowe i urządzenia do: obróbki cieplnej w próżni, obróbki cieplnej w atmosferach, lutowania wymienników ciepła w atmosferze ochronnej, obróbki cieplnej aluminium oraz metalurgii próżniowej. Działalność spółki dzieli się na cztery główne grupy produktów: piece próżniowe, linie do obróbki cieplnej aluminium i linie CAB, piece topialne oraz usługi serwisowe. Firma posiada spółki zależne w USA, Rosji, Chinach, Niemczech i Indiach, które zajmują się sprzedażą, produkcją i serwisem urządzeń do obróbki cieplnej metali na lokalnych rynkach.
#
# Company: WITTCHEN
# Description: Grupa prowadzi sprzedaż detaliczną i hurtową dodatków skórzanych, odzieży, obuwia oraz bagażu. Działalność realizowana jest poprzez sieć salonów własnych pod markami Wittchen i Wittchen Travel, kanał e-commerce oraz sprzedaż do klientów korporacyjnych. Na dzień 31 marca 2024 roku grupa prowadziła 103 salony własne o łącznej powierzchni 8 869 mkw., w tym 89 salonów pod marką Wittchen i 14 pod marką Wittchen Travel. Ponadto posiadała 10 salonów franczyzowych na Ukrainie. Spółka rozwija również sprzedaż zagraniczną, głównie poprzez własne sklepy internetowe oraz platformy typu marketplace na rynkach europejskich.
#
# Company: XPLUS
# Description: Spółka oferuje kompleksowe rozwiązania informatyczne z rodziny Microsoft Dynamics oraz własne produkty wertykalne dla budownictwa. W zakres działalności wchodzi diagnoza i analiza przedwdrożeniowa, doradztwo biznesowe, wdrożenia i wsparcie systemów informatycznych, projektowanie rozwiązań oraz rozwój oprogramowania. Oferta obejmuje systemy Microsoft Dynamics (AX, CRM, NAV) wspomagające zarządzanie przedsiębiorstwem, rozwiązania XCM i XPIW dla sektora budowlanego oraz zestaw 6 autorskich narzędzi z rodziny Dynamics Automated. Grupa świadczy usługi dla klientów w Polsce i za granicą.
#
# Company: XTPL
# Description: Spółka rozwija i komercjalizuje przełomową technologię ultraprecyzyjnego drukowania nanomateriałów, chronioną międzynarodowymi patentami. Technologia ta umożliwia tworzenie ultracienkich linii przewodzących o szerokości nawet 1 um, co jest nieosiągalne innymi metodami. Grupa oferuje trzy główne linie produktowe: moduły drukujące do integracji przemysłowej, urządzenia laboratoryjne Delta Printing System oraz nanotusze przewodzące. Rozwiązania te znajdują zastosowanie w branżach takich jak wyświetlacze, półprzewodniki, płytki PCB czy biosensory. Grupa intensywnie rozwija swoją działalność na kluczowych rynkach w Azji, Europie i USA, współpracując z globalnymi producentami elektroniki i ośrodkami badawczymi.
#
# Company: XTB
# Description: Grupa jest międzynarodowym dostawcą produktów, usług i rozwiązań technologicznych w zakresie obrotu instrumentami finansowymi. Specjalizuje się w rynku OTC, szczególnie w instrumentach pochodnych CFD, których zwrot zależy od zmian cen aktywów bazowych. Oferta obejmuje również inwestycje w akcje oraz instrumenty ETF na tej samej platformie transakcyjnej. Spółka prowadzi działalność w dwóch segmentach: detalicznym, oferując internetowy obrót instrumentami pochodnymi klientom indywidualnym, oraz instytucjonalnym, dostarczając płynność i technologie partnerom biznesowym. Grupa działa na podstawie licencji w Polsce, Wielkiej Brytanii, na Cyprze, w Belize i Zjednoczonych Emiratach Arabskich.
#
# Company: ZAMET
# Description: Grupa Zamet jest producentem wielkogabarytowych konstrukcji stalowych oraz maszyn i urządzeń dla przemysłu. Oferta obejmuje konstrukcje i urządzenia dla sektora offshore (wyposażenie platform wiertniczych, konstrukcje podwodne), urządzenia dźwigowe i przeładunkowe, osprzęt do maszyn ciężkich, maszyny i urządzenia dla hutnictwa i metalurgii oraz energetyki. Grupa świadczy również usługi obróbki metali, spawania i zabezpieczeń antykorozyjnych. Działalność produkcyjna prowadzona jest w zakładach w Piotrkowie Trybunalskim i Tarnowskich Górach. Odbiorcami są klienci z rynku krajowego i zagranicznego. Grupa działa w oparciu o model holdingowy, w którym Zamet SA sprawuje kontrolę nad podmiotami zależnymi.
#
# Company: PULAWY
# Description: Grupa Azoty Zakłady Azotowe "Puławy" SA prowadzi działalność w dwóch głównych segmentach: produktów nawozowych oraz produktów nienawozowych (głównie chemikaliów). Ofertę produktową firmy stanowią chemikalia (melamina i kaprolaktam); jednoskładnikowe nawozy azotowe (RSM, saletra amonowa magnezowana, siarczan amonu, mocznik); związki nadtlenowe (nadtlenek wodoru); gazy techniczne (ciekły azot, sprężony wodór, ciekły dwutlenek węgla). Spółka jest jednym z największych producentów melaminy w Polsce i trzecim na świecie. Jest też wiodącym polskim producentem kaprolaktamu i nawozów azotowych, saletry i mocznika. Około połowa produkcji jest eksportowana.
#
# Company: GRUPAAZOTY
# Description: Grupa Azoty jest jednym z kluczowych koncernów branży nawozowo-chemicznej w Europie. W jej skład wchodzą zakłady z Tarnowa, Puław, Polic i Kędzierzyna-Koźla. Grupa zajmuje drugą pozycję w Unii Europejskiej w produkcji nawozów azotowych i wieloskładnikowych. W ofercie znajdują się też produkty takie jak melamina, kaprolaktam, poliamid, alkohole OXO i biel tytanowa, które mają silną pozycję w sektorze chemicznym i znajdują zastosowanie w wielu gałęziach przemysłu. Grupa produkuje również tworzywa inżynieryjne, w tym poliamid 6. W zakładach Grupy wytwarzane są także półprodukty jak amoniak i kwas azotowy.
#
# Company: ZREMB
# Description: Spółka specjalizuje się w produkcji kontenerów i konstrukcji stalowych. Oferta obejmuje kontenery dla wojska, biurowe, wykorzystywane w branży offshore oraz do transportu odpadów. Grupa posiada rozbudowany park maszynowy, w tym urządzenia CNC, co pozwala na wytwarzanie produktów o wysokich parametrach technicznych i tolerancjach. Firma realizuje zamówienia dla sektora obronnego, w tym specjalistyczne kontenery dla sił zbrojnych. Znaczącą część produkcji stanowi eksport, głównie do krajów Unii Europejskiej. Spółka posiada własne patenty i prowadzi prace badawczo-rozwojowe nad innowacyjnymi rozwiązaniami w dziedzinie kontenerów.
#
# Company: POLICE
# Description: Grupa Azoty Zakłady Chemiczne "Police" S.A. to wiodący producent nawozów wieloskładnikowych i bieli tytanowej w Polsce. Spółka wytwarza nawozy, w tym Polifoskę i Polidap, oraz mocznik i nawóz azotowy z siarką. W segmencie pigmentów produkuje biel tytanową TYTANPOL oraz siarczan żelaza. Dodatkowo oferuje chemikalia, w tym amoniak i roztwory mocznika NOXy (AdBlue) i Pulnox. W I kwartale 2024 roku spółka zwiększyła produkcję nawozów o 14,3% r/r i bieli tytanowej o 9,5% r/r. Segment Nawozy stanowi główne źródło przychodów firmy, a Pigmenty drugie co do wielkości. Spółka boryka się z trudną sytuacją, prowadząc negocjacje z instytucjami finansującymi i pracując nad planem restrukturyzacji. Wyzwaniami pozostają niekorzystne relacje cenowe produktów do surowców oraz ograniczony popyt rynkowy. Firma koncentruje się na bieżącej działalności operacyjnej i optymalizacji procesów produkcyjnych.
#
# Company: ZEPAK
# Description: Grupa ZE PAK SA zajmuje się wytwarzaniem energii elektrycznej i ciepła. Główne aktywa wytwórcze to elektrownie opalane węglem brunatnym zlokalizowane w województwie wielkopolskim: Elektrownia Pątnów I, Elektrownia Pątnów II (z blokiem na parametry nadkrytyczne) oraz Elektrownia Konin. Spółka prowadzi również wydobycie węgla brunatnego w Kopalni Węgla Brunatnego Konin. Grupa rozwija także projekty w obszarze odnawialnych źródeł energii, w tym elektrowni fotowoltaicznych i farm wiatrowych. ZE PAK SA jest również zaangażowana w produkcję wodoru i rozwój technologii wodorowych.
#
# Company: OTMUCHOW
# Description: Grupa jest producentem słodyczy, słonych przekąsek i żelek. Specjalizuje się w wyrobach dla dużych sieci handlowych w segmencie private label oraz B2B. Oferuje produkty pod markami własnymi, a także kontraktowe. Główne kategorie to żelki, wyroby czekoladowe i słone przekąski. Spółka posiada zakłady produkcyjne w Otmuchowie, Nysie i Brzegu. W I kwartale 2024 roku grupa koncentrowała się na rozwoju segmentu żelek oraz ekspansji na rynkach zagranicznych, m.in. w Wielkiej Brytanii, Stanach Zjednoczonych i krajach azjatyckich. Po dacie bilansowej uruchomiono dwie nowe linie do produkcji żelek w zmodernizowanym zakładzie w Nysie.
#
# Company: HERKULES
# Description: Herkules SA jest wiodącym w Polsce dostawcą usług wynajmu urządzeń dźwigowych. Spółka dysponuje ponad 230 żurawiami wieżowymi, 28 żurawiami hydraulicznymi oraz żurawiami kratowymi. Oferuje usługi sprzętowe dla budownictwa infrastrukturalnego, drogowego, mieszkaniowego i energetycznego. Herkules S.A. świadczy także usługi budowlano-montażowe, w tym wznoszenie obiektów kubaturowych, farm wiatrowych oraz realizację obiektów telekomunikacyjnych i energetycznych. Spółka prowadzi działalność w sektorze energetyki odnawialnej, uczestnicząc w budowie farm wiatrowych. Dodatkowo Grupa Kapitałowa Herkules zajmuje się produkcją prefabrykatów strunobetonowych i kontenerów żelbetowych.
#
# Company: PGFGROUP
# Description: Grupa PGF działa głównie w branży odnawialnych źródeł energii, oferując kompleksowe usługi związane z fotowoltaiką. Zajmuje się projektowaniem, budową, montażem i serwisem instalacji fotowoltaicznych oraz doradztwem w zakresie pozyskiwania finansowania na te inwestycje. Grupa dostarcza również komponenty dla sektora pojazdów użytkowych, maszyn rolniczych i drogowych. Dodatkowo świadczy usługi napraw głównych silników wysokoprężnych i gazowych dla wojska, kolei i górnictwa. W strukturach Grupy znajdują się też podmioty zajmujące się rozwijaniem technologii bezzałogowych statków powietrznych oraz specjalizujące się w procesach związanych z wydobyciem gazu i ropy oraz produkcją energii elektrycznej z gazu ziemnego. Grupa zarządza także nieruchomościami komercyjnymi.
#
# Company: MANGATA
# Description: Grupa to holding przemysłowy działający w trzech segmentach operacyjnych. Segment podzespołów dla motoryzacji i komponentów dostarcza odkuwki oraz elementy obrabiane dla branży automotive, rolniczej i hydraulicznej. Segment armatury i automatyki przemysłowej produkuje armaturę przemysłową oraz odlewy. Segment elementów złącznych wytwarza śruby, nakrętki i inne elementy złączne. Produkty grupy są eksportowane do ponad 75 krajów. Spółki grupy posiadają zakłady produkcyjne w Polsce.
#
# Company: ZUE
# Description: Grupa świadczy kompleksowe usługi projektowania i realizacji w formule generalnego wykonawstwa budowy oraz modernizacji infrastruktury tramwajowej i kolejowej. Zakres prac obejmuje roboty ziemne, budowę podtorza, systemów odwadniających oraz obiektów inżynierskich i kubaturowych, w tym stacji. Spółka wykonuje również prace związane z sieciami trakcyjnymi, energetycznymi i teletechnicznymi. Działalność grupy koncentruje się głównie na rynku polskim, ale realizuje też projekty w innych krajach europejskich, w tym w Rumunii. Dodatkowo grupa prowadzi działalność handlową w zakresie materiałów i akcesoriów do budowy torowisk.
#
# Company: REINHOLD
# Description: Grupa prowadzi działalność deweloperską oraz inwestycje w gotowe projekty. Spółka realizuje inwestycje mieszkaniowe i biurowe w największych polskich miastach, takich jak Warszawa, Katowice, Kraków i Wrocław. Oferta obejmuje budowę i sprzedaż mieszkań, domów oraz powierzchni komercyjnych. Grupa posiada doświadczenie w realizacji projektów o różnej skali, od kameralnych inwestycji po duże osiedla mieszkaniowe i kompleksy biurowe. W swoich projektach spółka kładzie nacisk na funkcjonalność, nowoczesne rozwiązania architektoniczne oraz wysoką jakość wykonania.
#
# Company: KRKA
# Description: Grupa Krka jest innowacyjnym producentem leków generycznych. Podstawową działalnością jest produkcja i sprzedaż leków na receptę, które stanowią ponad 80% przychodów. Pozostałą część portfolio stanowią leki bez recepty oraz produkty weterynaryjne. Firma prowadzi własną działalność badawczo-rozwojową, wytwarzając substancje czynne i produkty końcowe. Produkcja odbywa się w zakładach w Słowenii, Rosji, Polsce, Chorwacji i Niemczech. Grupa posiada szeroką sieć sprzedaży i marketingu w ponad 70 krajach. Główne rynki to Europa Wschodnia, Europa Środkowa i Europa Zachodnia. Krka jest notowana na giełdach w Lublanie i Warszawie.
#
# Company: TATRY
# Description: TMR zarządza kilkoma kluczowymi ośrodkami narciarskimi w regionie. Do najważniejszych należą Tatrzańska Łomnica i Szczyrbskie Jezioro w Tatrach Wysokich na Słowacji, Jasná w Tatrach Niskich, również na Słowacji, oraz Szczyrk Mountain Resort w polskich Beskidach.W portfolio spółki znajdują się także parki rozrywki. Tatralandia, największy całoroczny aquapark w Europie Środkowej, zlokalizowany jest na Słowacji. Z kolei w Polsce TMR zarządza Śląskim Wesołym Miasteczkiem, znanym również jako Legendia, które znajduje się w Chorzowie.Spółka posiada i zarządza siecią hoteli w pobliżu swoich ośrodków, oferując łącznie ponad 2000 miejsc noclegowych. Działalność TMR koncentruje się głównie na Słowacji, Polsce i Czechach, jednak firma stopniowo rozszerza swój zasięg na inne kraje regionu.Strategia biznesowa TMR opiera się na tworzeniu kompleksowej oferty turystycznej, która łączy atrakcje górskie, parki rozrywki i bazę noclegową. Spółka jest znana z inwestycji w infrastrukturę narciarską, modernizację ośrodków i rozszerzanie oferty turystycznej, co przyczynia się do rozwoju turystyki w regionie Europy Środkowo-Wschodniej.Spółka jest notowana na giełdach w Bratysławie, Pradze i Warszawie.
#
# Company: HUUUGE
# Description: Grupa jest globalnym deweloperem i wydawcą gier typu free-to-play. Jej misją jest zaoferowanie miliardom ludzi wspólnej zabawy, a wizją - umożliwienie społecznych interakcji użytkownikom gier mobilnych. Dąży do tego, aby stać się światowym liderem w grach free-to-play w czasie rzeczywistym, zapewniających jak najwięcej radości i zabawy graczom na całym świecie. Gry grupy co miesiąc zapewniają rozrywkę milionom użytkowników z 174 krajów i są dostępne w 32 językach. Flagowymi produktami są Huuuge Casino i Billionaire Casino, które wygenerowały 97% łącznych przychodów w I kwartale 2024 r. Obie gry oferują graczom ponad 100 automatów do gry, gry karciane i ruletkę. Umożliwiają też dołączenie do klubów i rywalizację w ramach Billionaire League.
#
# Company: SILVAIR-REGS
# Description: Grupa działa w obszarze Internetu Rzeczy (IoT), opracowując innowacyjną technologię bezprzewodowej komunikacji urządzeń w topologii sieci kratowej. Głównym produktem jest oprogramowanie i usługi do inteligentnych systemów oświetlenia. Strategicznym celem jest osiągnięcie wiodącej pozycji na rynku dostawców rozwiązań IoT wykorzystujących technologię opartą na standardzie Bluetooth Mesh. Grupa oferuje producentom komponentów oprogramowanie układowe Silvair Firmware do integracji z urządzeniami oraz platformę Silvair Platform do konfiguracji i zarządzania sieciami oświetleniowymi. Produkty umożliwiają m.in. automatyzację procesów zarządzania infrastrukturą, monitorowanie zużycia energii i optymalizację wykorzystania przestrzeni w budynkach komercyjnych.
